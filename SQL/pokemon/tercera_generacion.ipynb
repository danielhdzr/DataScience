# %%
import pandas as pd
import sqlite3
import requests
from bs4 import BeautifulSoup
from io import StringIO

url = 'https://pokemon.fandom.com/es/wiki/Lista_de_Pokémon'
web_site = requests.get(url)

soup = BeautifulSoup(web_site.text, 'html.parser')

html_str = str(soup)

html_io = StringIO(html_str)
# El primer parametro de pd.read_html es el file path/
# A final de cuentas termina leyendo la url
tables = pd.read_html(html_io)

conn = sqlite3.connect('pokemon.db')

for index, table in enumerate(tables):
    print('*****************************************************')
    print('*****************************************************')
    print(f'index {index}')
    print(f'table {table}')
# Out:
# *****************************************************
# *****************************************************
# index 0
# table     0                                                  1
# 0 NaN  Está página tiene un gran tamaño. Si tu navega...
# *****************************************************
# *****************************************************
# index 1
# table                   0                                                  1    2
# 0  Ir a la sección:  Primera generación • Segunda generación • Terc...    ↑
# 1  Ir a la sección:  Cuarta generación • Quinta generación • Sexta ...  NaN
# 2  Ir a la sección:             Séptima generación • Octava generación    ↓
# *****************************************************
# *****************************************************
# index 2
# table        #      Nombre    Tipo 1    Tipo 2 Japonés   Romanizado Rom. oficial  \
# 0      1   Bulbasaur    Planta    Veneno   フシギダネ  Fushigidane  Fushigidane
# 1      2     Ivysaur    Planta    Veneno   フシギソウ    Fushigisō   Fushigisou
# 2      3    Venusaur    Planta    Veneno   フシギバナ  Fushigibana  Fushigibana
# 3      4  Charmander     Fuego     Fuego    ヒトカゲ     Hitokage     Hitokage
# 4      5  Charmeleon     Fuego     Fuego    リザード       Rizādo      Lizardo
# ..   ...         ...       ...       ...     ...          ...          ...
# 146  147     Dratini    Dragón    Dragón   ミニリュウ      Miniryū      Miniryu
# 147  148   Dragonair    Dragón    Dragón   ハクリュー      Hakuryū      Hakuryu
# 148  149   Dragonite    Dragón   Volador   カイリュー       Kairyū       Kairyu
# 149  150      Mewtwo  Psíquico  Psíquico   ミュウツー       Myūtsū       Mewtwo
# 150  151         Mew  Psíquico  Psíquico     ミュウ          Myū          Mew
#
#      G. hvo 1 G. hvo 2  JOH  HOE  SIN  TES1    KAL    ALO    GAL
# 0    Monstruo   Planta  226  NaN  NaN   NaN  080CE    NaN    NaN
# 1    Monstruo   Planta  227  NaN  NaN   NaN  081CE    NaN    NaN
# 2    Monstruo   Planta  228  NaN  NaN   NaN  082CE    NaN    NaN
# 3    Monstruo   Dragón  229  NaN  NaN   NaN  083CE    NaN  378.0
# 4    Monstruo   Dragón  230  NaN  NaN   NaN  084CE    NaN  379.0
# ..        ...      ...  ...  ...  ...   ...    ...    ...    ...
# 146    Agua 1   Dragón  241  NaN  NaN   NaN  145MO  281.0    NaN
# 147    Agua 1   Dragón  242  NaN  NaN   NaN  146MO  282.0    NaN
# 148    Agua 1   Dragón  243  NaN  NaN   NaN  147MO  283.0    NaN
# 149   Ninguno      NaN  249  NaN  NaN   NaN  151MO    NaN    NaN
# 150   Ninguno      NaN  250  NaN  NaN   NaN    NaN    NaN    NaN
#
# [151 rows x 16 columns]
# *****************************************************
# *****************************************************
# index 3
# table                   0                                                  1    2
# 0  Ir a la sección:  Primera generación • Segunda generación • Terc...    ↑
# 1  Ir a la sección:  Cuarta generación • Quinta generación • Sexta ...  NaN
# 2  Ir a la sección:             Séptima generación • Octava generación    ↓
# *****************************************************
# *****************************************************
# index 4
# table       #     Nombre    Tipo 1     Tipo 2 Japonés   Romanizado Rom. oficial  \
# 0   152  Chikorita    Planta     Planta   チコリータ    Chikorīta    Chicorita
# 1   153    Bayleef    Planta     Planta   ベイリーフ      Beirīfu      Bayleaf
# 2   154   Meganium    Planta     Planta   メガニウム    Meganiumu     Meganium
# 3   155  Cyndaquil     Fuego      Fuego   ヒノアラシ   Hinoarashi   Hinoarashi
# 4   156    Quilava     Fuego      Fuego   マグマラシ  Magumarashi   Magmarashi
# ..  ...        ...       ...        ...     ...          ...          ...
# 95  247    Pupitar      Roca     Tierra   サナギラス   Sanagirasu    Sanagiras
# 96  248  Tyranitar      Roca  Siniestro   バンギラス    Bangirasu     Bangiras
# 97  249      Lugia  Psíquico    Volador     ルギア        Rugia        Lugia
# 98  250      Ho-Oh     Fuego    Volador    ホウオウ          Hōō        Houou
# 99  251     Celebi  Psíquico     Planta    セレビィ      Serebyi       Celebi
#
#     G. hvo 1 G. hvo 2  JOH  HOE  SIN   TES1    KAL  ALO
# 0   Monstruo   Planta    1  NaN  NaN    NaN    NaN  NaN
# 1   Monstruo   Planta    2  NaN  NaN    NaN    NaN  NaN
# 2   Monstruo   Planta    3  NaN  NaN    NaN    NaN  NaN
# 3      Campo      NaN    4  NaN  NaN    NaN    NaN  NaN
# 4      Campo      NaN    5  NaN  NaN    NaN    NaN  NaN
# ..       ...      ...  ...  ...  ...    ...    ...  ...
# 95  Monstruo      NaN  245  NaN  NaN  293.0  103MO  NaN
# 96  Monstruo      NaN  246  NaN  NaN  294.0  104MO  NaN
# 97   Ninguno      NaN  247  NaN  NaN    NaN    NaN  NaN
# 98   Ninguno      NaN  248  NaN  NaN    NaN    NaN  NaN
# 99   Ninguno      NaN  251  NaN  NaN    NaN    NaN  NaN
#
# [100 rows x 15 columns]
# *****************************************************
# *****************************************************
# index 5
# table                   0                                                  1    2
# 0  Ir a la sección:  Primera generación • Segunda generación • Terc...    ↑
# 1  Ir a la sección:  Cuarta generación • Quinta generación • Sexta ...  NaN
# 2  Ir a la sección:             Séptima generación • Octava generación    ↓
# *****************************************************
# *****************************************************
# index 6
# table        #     Nombre    Tipo 1    Tipo 2 Japonés  Romanizado Rom. oficial  \
# 0    252    Treecko    Planta    Planta     キモリ      Kimori       Kimori
# 1    253    Grovyle    Planta    Planta   ジュプトル    Juputoru      Juptile
# 2    254   Sceptile    Planta    Planta   ジュカイン      Jukain       Jukain
# 3    255    Torchic     Fuego     Fuego    アチャモ      Achamo       Achamo
# 4    256  Combusken     Fuego     Lucha   ワカシャモ   Wakashamo    Wakasyamo
# ..   ...        ...       ...       ...     ...         ...          ...
# 130  382     Kyogre      Agua      Agua   カイオーガ      Kaiōga       Kyogre
# 131  383    Groudon    Tierra    Tierra   グラードン     Gurādon      Groudon
# 132  384   Rayquaza    Dragón   Volador   レックウザ     Rekkūza     Rayquaza
# 133  385    Jirachi     Acero  Psíquico    ジラーチ     Jirāchi      Jirachi
# 134  386     Deoxys  Psíquico  Psíquico   デオキシス  Deokishisu       Deoxys
#
#      G. hvo 1 G. hvo 2  JOH  HOE  SIN  TES1  KAL  ALO
# 0    Monstruo   Dragón  NaN    1  NaN   NaN  NaN  NaN
# 1    Monstruo   Dragón  NaN    2  NaN   NaN  NaN  NaN
# 2    Monstruo   Dragón  NaN    3  NaN   NaN  NaN  NaN
# 3       Campo      NaN  NaN    4  NaN   NaN  NaN  NaN
# 4       Campo      NaN  NaN    5  NaN   NaN  NaN  NaN
# ..        ...      ...  ...  ...  ...   ...  ...  ...
# 130   Ninguno      NaN  NaN  198  NaN   NaN  NaN  NaN
# 131   Ninguno      NaN  NaN  199  NaN   NaN  NaN  NaN
# 132   Ninguno      NaN  NaN  200  NaN   NaN  NaN  NaN
# 133   Ninguno      NaN  NaN  201  NaN   NaN  NaN  NaN
# 134   Ninguno      NaN  NaN  202  NaN   NaN  NaN  NaN
#
# [135 rows x 15 columns]
# *****************************************************
# *****************************************************
# index 7
# table                   0                                                  1    2
# 0  Ir a la sección:  Primera generación • Segunda generación • Terc...    ↑
# 1  Ir a la sección:  Cuarta generación • Quinta generación • Sexta ...  NaN
# 2  Ir a la sección:             Séptima generación • Octava generación    ↓
# *****************************************************
# *****************************************************
# index 8
# table        #    Nombre     Tipo 1     Tipo 2 Japonés   Romanizado Rom. oficial  \
# 0    387   Turtwig     Planta     Planta    ナエトル      Naetoru       Naetle
# 1    388    Grotle     Planta     Planta   ハヤシガメ  Hayashigame  Hayashigame
# 2    389  Torterra     Planta     Tierra   ドダイトス    Dodaitosu    Dodaitose
# 3    390  Chimchar      Fuego      Fuego    ヒコザル     Hikozaru     Hikozaru
# 4    391  Monferno      Fuego      Lucha   モウカザル     Mōkazaru    Moukazaru
# ..   ...       ...        ...        ...     ...          ...          ...
# 102  489    Phione       Agua       Agua    フィオネ        Fione       Phione
# 103  490   Manaphy       Agua       Agua    マナフィ       Manafi      Manaphy
# 104  491   Darkrai  Siniestro  Siniestro   ダークライ      Dākurai      Darkrai
# 105  492   Shaymin     Planta     Planta    シェイミ       Sheimi      Shaymin
# 106  493    Arceus     Normal     Normal   アルセウス     Aruseusu       Arceus
#
#      G. hvo 1   G. hvo 2  JOH  HOE    SIN  TES1  KAL  ALO
# 0    Monstruo     Planta  NaN  NaN    1.0   NaN  NaN  NaN
# 1    Monstruo     Planta  NaN  NaN    2.0   NaN  NaN  NaN
# 2    Monstruo     Planta  NaN  NaN    3.0   NaN  NaN  NaN
# 3       Campo  Humanoide  NaN  NaN    4.0   NaN  NaN  NaN
# 4       Campo  Humanoide  NaN  NaN    5.0   NaN  NaN  NaN
# ..        ...        ...  ...  ...    ...   ...  ...  ...
# 102    Agua 1       Hada  NaN  NaN    NaN   NaN  NaN  NaN
# 103    Agua 1       Hada  NaN  NaN  151.0   NaN  NaN  NaN
# 104   Ninguno        NaN  NaN  NaN    NaN   NaN  NaN  NaN
# 105   Ninguno        NaN  NaN  NaN    NaN   NaN  NaN  NaN
# 106   Ninguno        NaN  NaN  NaN    NaN   NaN  NaN  NaN
#
# [107 rows x 15 columns]
# *****************************************************
# *****************************************************
# index 9
# table                   0                                                  1    2
# 0  Ir a la sección:  Primera generación • Segunda generación • Terc...    ↑
# 1  Ir a la sección:  Cuarta generación • Quinta generación • Sexta ...  NaN
# 2  Ir a la sección:             Séptima generación • Octava generación    ↓
# *****************************************************
# *****************************************************
# index 10
# table        #     Nombre    Tipo 1    Tipo 2 Japonés  Romanizado Rom. oficial  \
# 0    494    Victini  Psíquico     Fuego   ビクティニ    Bikutini      Victini
# 1    495      Snivy    Planta    Planta   ツタージャ     Tsutāja     Tsutarja
# 2    496    Servine    Planta    Planta   ジャノビー      Janobī       Janovy
# 3    497  Serperior    Planta    Planta   ジャローダ      Jarōda      Jalorda
# 4    498      Tepig     Fuego     Fuego     ポカブ      Pokabu       Pokabu
# ..   ...        ...       ...       ...     ...         ...          ...
# 151  645   Landorus    Tierra   Volador   ランドロス   Randorosu      Landlos
# 152  646     Kyurem    Dragón     Hielo    キュレム     Kyuremu       Kyurem
# 153  647     Keldeo      Agua     Lucha   ケルディオ     Kerudio       Keldeo
# 154  648   Meloetta    Normal  Psíquico   メロエッタ    Meroetta       Meloia
# 155  649   Genesect     Bicho     Acero   ゲノセクト  Genosekuto     Genesect
#
#     G. hvo 1 G. hvo 2  JOH  HOE  SIN  TES  KAL  ALO
# 0    Ninguno      NaN  NaN  NaN  NaN    0  NaN  NaN
# 1      Campo   Planta  NaN  NaN  NaN    1  NaN  NaN
# 2      Campo   Planta  NaN  NaN  NaN    2  NaN  NaN
# 3      Campo   Planta  NaN  NaN  NaN    3  NaN  NaN
# 4      Campo      NaN  NaN  NaN  NaN    4  NaN  NaN
# ..       ...      ...  ...  ...  ...  ...  ...  ...
# 151  Ninguno      NaN  NaN  NaN  NaN  151  NaN  NaN
# 152  Ninguno      NaN  NaN  NaN  NaN  152  NaN  NaN
# 153  Ninguno      NaN  NaN  NaN  NaN  153  NaN  NaN
# 154  Ninguno      NaN  NaN  NaN  NaN  154  NaN  NaN
# 155  Ninguno      NaN  NaN  NaN  NaN  155  NaN  NaN
#
# [156 rows x 15 columns]
# *****************************************************
# *****************************************************
# index 11
# table                   0                                                  1    2
# 0  Ir a la sección:  Primera generación • Segunda generación • Terc...    ↑
# 1  Ir a la sección:  Cuarta generación • Quinta generación • Sexta ...  NaN
# 2  Ir a la sección:             Séptima generación • Octava generación    ↓
# *****************************************************
# *****************************************************
# index 12
# table       #      Nombre     Tip. 1    Tip. 2  Japns.  Romanizado Rom. oficial  \
# 0   650     Chespin     Planta    Planta   ハリマロン   Harimaron    Harimaron
# 1   651   Quilladin     Planta    Planta   ハリボーグ    Haribōgu     Hariborg
# 2   652  Chesnaught     Planta     Lucha   ブリガロン   Burigaron    Brigarron
# 3   653    Fennekin      Fuego     Fuego    フォッコ       Fokko        Fokko
# 4   654     Braixen      Fuego     Fuego   テールナー      Tērunā     Tairenar
# ..  ...         ...        ...       ...     ...         ...          ...
# 67  717     Yveltal  Siniestro   Volador   イベルタル   Iberutaru      Yveltal
# 68  718     Zygarde     Dragón    Tierra    ジガルデ    Jigarude      Zygarde
# 69  719     Diancie       Roca      Hada  ディアンシー     Dianshī      Diancie
# 70  720       Hoopa   Psíquico  Fantasma     フーパ        Fūpa        Hoopa
# 71  721   Volcanion      Fuego      Agua  ボルケニオン  Borukenion    Volcanion
#
#     G. hv 1 G. hv 2  JOH  HOE  SIN  TES    KAL    ALO
# 0     Campo     NaN  NaN  NaN  NaN  NaN  001CE    NaN
# 1     Campo     NaN  NaN  NaN  NaN  NaN  002CE    NaN
# 2     Campo     NaN  NaN  NaN  NaN  NaN  003CE    NaN
# 3     Campo     NaN  NaN  NaN  NaN  NaN  004CE    NaN
# 4     Campo     NaN  NaN  NaN  NaN  NaN  005CE    NaN
# ..      ...     ...  ...  ...  ...  ...    ...    ...
# 67  Ninguno     NaN  NaN  NaN  NaN  NaN  149MO    NaN
# 68  Ninguno     NaN  NaN  NaN  NaN  NaN  150MO  205.0
# 69  Ninguno     NaN  NaN  NaN  NaN  NaN  151CE    NaN
# 70  Ninguno     NaN  NaN  NaN  NaN  NaN  152CE    NaN
# 71  Ninguno     NaN  NaN  NaN  NaN  NaN  153CE    NaN
#
# [72 rows x 15 columns]
# *****************************************************
# *****************************************************
# index 13
# table                   0                                                  1    2
# 0  Ir a la sección:  Primera generación • Segunda generación • Terc...    ↑
# 1  Ir a la sección:  Cuarta generación • Quinta generación • Sexta ...  NaN
# 2  Ir a la sección:             Séptima generación • Octava generación    ↓
# *****************************************************
# *****************************************************
# index 14
# table       #  Mini sprite       Nombre     Tip. 1     Tip. 2   Japo.    Romanizado  \
# 0   722          NaN       Rowlet     Planta    Volador    モクロー        Mokurō
# 1   723          NaN      Dartrix     Planta    Volador   フクスロー      Fukusurō
# 2   724          NaN    Decidueye     Planta   Fantasma  ジュナイパー       Junaipā
# 3   725          NaN       Litten      Fuego      Fuego    ニャビー         Nyabī
# 4   726          NaN     Torracat      Fuego      Fuego   ニャヒート       Nyahīto
# ..  ...          ...          ...        ...        ...     ...           ...
# 83  805          NaN    Stakataka       Roca      Acero  ツンデツンデ  Tsundetsunde
# 84  806          NaN  Blacephalon      Fuego   Fantasma   ズガドーン       Zugadōn
# 85  807          NaN      Zeraora  Eléctrico  Eléctrico    ゼラオラ       Zeraora
# 86  808          NaN       Meltan      Acero      Acero    メルタン       Merutan
# 87  809          NaN     Melmetal      Acero      Acero   メルメタル    Merumetaru
#
#    Rom. oficial  G. hv 1 G. hv 2  JOH  HOE  SIN  TES  KAL  ALO
# 0       Mokuroh  Volador     NaN  NaN  NaN  NaN  NaN  NaN  001
# 1     Fukuthrow  Volador     NaN  NaN  NaN  NaN  NaN  NaN  002
# 2      Junaiper  Volador     NaN  NaN  NaN  NaN  NaN  NaN  003
# 3        Nyabby    Campo     NaN  NaN  NaN  NaN  NaN  NaN  004
# 4       Nyaheat    Campo     NaN  NaN  NaN  NaN  NaN  NaN  005
# ..          ...      ...     ...  ...  ...  ...  ...  ...  ...
# 83            ?      NaN     NaN  NaN  NaN  NaN  NaN  NaN  392
# 84            ?      NaN     NaN  NaN  NaN  NaN  NaN  NaN  393
# 85            ?      NaN     NaN  NaN  NaN  NaN  NaN  NaN  403
# 86            ?      NaN     NaN  NaN  NaN  NaN  NaN  NaN    ?
# 87          NaN      NaN     NaN  NaN  NaN  NaN  NaN  NaN    ?
#
# [88 rows x 16 columns]
# *****************************************************
# *****************************************************
# index 15
# table                   0                                                  1    2
# 0  Ir a la sección:  Primera generación • Segunda generación • Terc...    ↑
# 1  Ir a la sección:  Cuarta generación • Quinta generación • Sexta ...  NaN
# 2  Ir a la sección:             Séptima generación • Octava generación    ↓
# *****************************************************
# *****************************************************
# index 16
# table        # Mini sprite                  Nombre     Tip. 1    Tip. 2   Japo.  \
# 0    550         NaN  Basculin raya blanca25       Agua      Agua    バスラオ
# 1    810         NaN                 Grookey     Planta    Planta    サルノリ
# 2    811         NaN                Thwackey     Planta    Planta   バチンキー
# 3    812         NaN               Rillaboom     Planta    Planta  ゴリランダー
# 4    813         NaN               Scorbunny      Fuego     Fuego    ヒバニー
# ..   ...         ...                     ...        ...       ...     ...
# 96   901    Ursaluna                Ursaluna     Tierra    Normal    ガチグマ
# 97   902         NaN             Basculegion       Agua  Fantasma   イダイトウ
# 98   903    Sneasler                Sneasler     Veneno     Lucha  オオニューラ
# 99   904    Overqwil                Overqwil  Siniestro    Veneno   ハリーマン
# 100  905    Enamorus                Enamorus       Hada   Volador   ラブトロス
#
#     Romanizado Rom. oficial G. hv 1    G. hv 2
# 0      Bassrao          NaN  Agua 2    Ninguno
# 1     Sarunori          NaN   Campo     Planta
# 2     Bachinkī          NaN   Campo     Planta
# 3    Gorirandā          NaN   Campo     Planta
# 4       Hibanī          NaN   Campo  Humanoide
# ..         ...          ...     ...        ...
# 96   Gachiguma          NaN     NaN    Ninguno
# 97     Idaitou          NaN  Agua 2    Ninguno
# 98     Ohnyula          NaN     NaN    Ninguno
# 99     Haryman          NaN     NaN    Ninguno
# 100  Lovetolos          NaN     NaN    Ninguno
#
# [101 rows x 10 columns]
# *****************************************************
# *****************************************************
# index 17
# table                   0                                                  1    2
# 0  Ir a la sección:  Primera generación • Segunda generación • Terc...    ↑
# 1  Ir a la sección:  Cuarta generación • Quinta generación • Sexta ...  NaN
# 2  Ir a la sección:             Séptima generación • Octava generación    ↓
# *****************************************************
# *****************************************************
# index 18
# table                       Clasificaciones de los Pokémon  \
#                                          Por Pokédex
# 0  Pokédex Nacional Kanto (1ª gen.) Johto (2ª gen...
#
#                                                       \
#                                        Por atributos
# 0  Por tipos Por grupos huevo Por especie Por alt...
#
#                                                       \
#                                     Por estadísticas
# 0  Por estadísticas base Por ratio de captura Por...
#
#
#                                           Miscelánea
# 0  Alfabéticamente Numéricamente Por generación P...

# %%
    df = pd.DataFrame(tables[6])
    df
# Out:
#        #     Nombre    Tipo 1    Tipo 2 Japonés  Romanizado Rom. oficial  \
# 0    252    Treecko    Planta    Planta     キモリ      Kimori       Kimori
# 1    253    Grovyle    Planta    Planta   ジュプトル    Juputoru      Juptile
# 2    254   Sceptile    Planta    Planta   ジュカイン      Jukain       Jukain
# 3    255    Torchic     Fuego     Fuego    アチャモ      Achamo       Achamo
# 4    256  Combusken     Fuego     Lucha   ワカシャモ   Wakashamo    Wakasyamo
# ..   ...        ...       ...       ...     ...         ...          ...
# 130  382     Kyogre      Agua      Agua   カイオーガ      Kaiōga       Kyogre
# 131  383    Groudon    Tierra    Tierra   グラードン     Gurādon      Groudon
# 132  384   Rayquaza    Dragón   Volador   レックウザ     Rekkūza     Rayquaza
# 133  385    Jirachi     Acero  Psíquico    ジラーチ     Jirāchi      Jirachi
# 134  386     Deoxys  Psíquico  Psíquico   デオキシス  Deokishisu       Deoxys
#
#      G. hvo 1 G. hvo 2  JOH  HOE  SIN  TES1  KAL  ALO
# 0    Monstruo   Dragón  NaN    1  NaN   NaN  NaN  NaN
# 1    Monstruo   Dragón  NaN    2  NaN   NaN  NaN  NaN
# 2    Monstruo   Dragón  NaN    3  NaN   NaN  NaN  NaN
# 3       Campo      NaN  NaN    4  NaN   NaN  NaN  NaN
# 4       Campo      NaN  NaN    5  NaN   NaN  NaN  NaN
# ..        ...      ...  ...  ...  ...   ...  ...  ...
# 130   Ninguno      NaN  NaN  198  NaN   NaN  NaN  NaN
# 131   Ninguno      NaN  NaN  199  NaN   NaN  NaN  NaN
# 132   Ninguno      NaN  NaN  200  NaN   NaN  NaN  NaN
# 133   Ninguno      NaN  NaN  201  NaN   NaN  NaN  NaN
# 134   Ninguno      NaN  NaN  202  NaN   NaN  NaN  NaN
#
# [135 rows x 15 columns]

# %%
    try:
        table = tables[6]
        table_name = 'tercera_generacion'
        table.to_sql(table_name, conn, if_exists='replace', index=False)
        print(f"Tabla '{table_name}' exportada a base de datos 'pokemon.db'")
    except Exception as e:
        print(f"Error al exportar tabla '{table_name}'. Error: {e}")

conn.commit()
conn.close()
# Out:
# Tabla 'tercera_generacion' exportada a base de datos 'pokemon.db'
